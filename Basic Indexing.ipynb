# %%
#Basic Indexing
import numpy as np

arr=np.array([10,20,30,40,50])
print("Single element access:",arr[1])
print("Negative value accessing:",arr[-5])

arr2d=np.array([[1,2,3],[4,5,6]])
print("Multidimensional array access:",arr2d[1,2])
# Out:
# Single element access: 20
# Negative value accessing: 10
# Multidimensional array access: 6
